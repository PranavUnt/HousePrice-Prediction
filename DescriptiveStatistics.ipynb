# %% [markdown]
# ## Descriptive Statistics

# %%
import pandas as pd
data=pd.read_excel('final project data 1.xlsx')
print("The dataset is")
data
# Out:
# The dataset is
#        Record  Sale_amount  Sale_date  Beds  Baths  Sqft_home  Sqft_lot  \
# 0           1       295000 2016-05-31     5   3.00       2020   38332.8
# 1           2       240000 2016-06-20     4   2.00       1498   54014.4
# 2           3       385000 2016-05-31     5   4.00       4000   85813.2
# 3           4       268000 2016-04-12     3   2.50       2283  118918.8
# 4           5       186000 2016-04-05     3   1.25       1527   15681.6
# ...       ...          ...        ...   ...    ...        ...       ...
# 10654   10655       320000 2016-06-07     3   2.00       1870   13068.0
# 10655   10656       359100 2016-04-08     5   4.50       2119   11325.6
# 10656   10657       349646 2016-06-13     3   1.75       1949   14374.8
# 10657   10658       288000 2016-04-16     4   4.00       2710   10890.0
# 10658   10659       330000 2016-07-01     4   3.00       2702   13068.0
#
#                 Type  Build_year                      Town  \
# ...

# %% [markdown]
# The selected dataset is about the Sale amount of home relation with other features like Date of Sale, No. of Bedrooms,	No. of Bathrooms, Square feet of home...etc

# %%
N=len(data)
print("The total number of entries (rows) in the dataset: ",N)
# Out:
# The total number of entries (rows) in the dataset:  10659

# %%
print("The total number of features (columns) in the dataset: ", data.shape[1])
# Out:
# The total number of features (columns) in the dataset:  11

# %% [markdown]
# Breif data description

# %%
#Excluding Sale_date as it is not quantitative
data1=data[['Record', 'Sale_amount', 'Beds', 'Baths', 'Sqft_home','Sqft_lot', 'Type', 'Build_year', 'Town', 'University']] #Filtered data


describe=data1.describe()
describe_s = describe.style.background_gradient(cmap='YlOrRd')
describe_s
# Out:
# <style type="text/css">
# #T_5d373_row0_col0, #T_5d373_row0_col2, #T_5d373_row0_col3, #T_5d373_row0_col6, #T_5d373_row7_col0, #T_5d373_row7_col1, #T_5d373_row7_col4, #T_5d373_row7_col5 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_5d373_row0_col1, #T_5d373_row0_col5, #T_5d373_row1_col2, #T_5d373_row1_col3, #T_5d373_row2_col2, #T_5d373_row2_col3, #T_5d373_row2_col6, #T_5d373_row3_col0, #T_5d373_row3_col1, #T_5d373_row3_col2, #T_5d373_row3_col3, #T_5d373_row3_col4, #T_5d373_row3_col5, #T_5d373_row4_col2, #T_5d373_row4_col3, #T_5d373_row4_col5, #T_5d373_row5_col2, #T_5d373_row5_col3, #T_5d373_row5_col5, #T_5d373_row6_col2, #T_5d373_row6_col3, #T_5d373_row6_col5, #T_5d373_row7_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_5d373_row0_col4 {
#   background-color: #fff5b3;
#   color: #000000;
# }
# #T_5d373_row1_col0, #T_5d373_row5_col0 {
#   background-color: #fd8c3c;
#   color: #f1f1f1;
# }
# #T_5d373_row1_col1, #T_5d373_row2_col1 {
# ...

# %%
data.loc[0]
# Out:
# Record                             1
# Sale_amount                   295000
# Sale_date        2016-05-31 00:00:00
# Beds                               5
# Baths                            3.0
# Sqft_home                       2020
# Sqft_lot                     38332.8
# Type                   Single Family
# Build_year                      1976
# Town                        Ames, IA
# University     Iowa State University
# Name: 0, dtype: object

# %% [markdown]
# ### 1. Measures of Central Tendency

# %% [markdown]
# Mean: The average value each feature of the dataset.

# %%
print('The mean of the feature Sale_amount: ')
mean1=data['Sale_amount'].mean().round(3)
print(mean1)
# Out:
# The mean of the feature Sale_amount:
# 337556.405

# %%
print('The mean of the feature Beds: ')
mean2=data['Beds'].mean().round(3)
print(mean2)
# Out:
# The mean of the feature Beds:
# 3.433

# %%
print('The mean of the feature Baths: ')
mean3=data['Baths'].mean().round(3)
print(mean3)
# Out:
# The mean of the feature Baths:
# 2.346

# %%
print('The mean of the feature Sqft_home: ')
mean4=data['Sqft_home'].mean().round(3)
print(mean4)
# Out:
# The mean of the feature Sqft_home:
# 2072.743

# %%
print('The mean of the feature Sqft_lot: ')
mean5=data['Sqft_lot'].mean().round(3)
print(mean5)
# Out:
# The mean of the feature Sqft_lot:
# 20468.858

# %%
print('The mean of the feature Build_year: ')
mean6=data['Build_year'].mean().round(3)
print(mean6)
# Out:
# The mean of the feature Build_year:
# 1968.266

# %% [markdown]
# Median: The middle value in the dataset when it is sorted in ascending order.

# %%
print('The median of the feature Sale_amount: ')
med1=data['Sale_amount'].median().round(3)
print(med1)
# Out:
# The median of the feature Sale_amount:
# 249000.0

# %%
print('The median of the feature Beds: ')
med2=data['Beds'].median().round(3)
print(med2)
# Out:
# The median of the feature Beds:
# 3.0

# %%
print('The median of the feature Baths: ')
med3=data['Baths'].median().round(3)
print(med3)
# Out:
# The median of the feature Baths:
# 2.0

# %%
print('The median of the feature Sqft_home: ')
med4=data['Sqft_home'].median().round(3)
print(med4)
# Out:
# The median of the feature Sqft_home:
# 1826.0

# %%
print('The median of the feature Sqft_lot: ')
med5=data['Sqft_lot'].median().round(3)
print(med5)
# Out:
# The median of the feature Sqft_lot:
# 8712.0

# %%
print('The median of the feature Build_year: ')
med6=data['Build_year'].median().round(3)
print(med6)
# Out:
# The median of the feature Build_year:
# 1973.0

# %% [markdown]
# Mode: The most frequently occurring value(s) in the dataset.

# %%
import statistics

# %%
print('The mode of the feature Sale_amount: ')
mode1=statistics.mode(data['Sale_amount'])
print(mode1)
# Out:
# The mode of the feature Sale_amount:
# 250000

# %%
print('The mode of the feature Beds: ')
mode2=statistics.mode(data['Beds'])
print(mode2)
# Out:
# The mode of the feature Beds:
# 3

# %%
print('The mode of the feature Baths: ')
mode3=statistics.mode(data['Baths'])
print(mode3)
# Out:
# The mode of the feature Baths:
# 2.0

# %%
print('The mode of the feature sqs: ')
mode4=statistics.mode(data['Sqft_home'])
print(mode4)
# Out:
# The mode of the feature sqs:
# 1600

# %%
print('The mode of the feature Square feet of lot: ')
mode5=statistics.mode(data['Sqft_lot'])
print(mode5)
# Out:
# The mode of the feature Square feet of lot:
# 7405.0

# %%
print('The mode of the feature Type: ')
statistics.mode(data['Type'])
# Out:
# The mode of the feature Type:
# 'Single Family'

# %%
print('The mode of the feature Build_year: ')
mode6=statistics.mode(data['Build_year'])
print(mode6)
# Out:
# The mode of the feature Build_year:
# 2004

# %%
print('The mode of the feature Town: ')
statistics.mode(data['Town'])
# Out:
# The mode of the feature Town:
# 'Eugene, OR'

# %%
print('The mode of the feature University: ')
statistics.mode(data['University'])
# Out:
# The mode of the feature University:
# 'University of Oregon'

# %% [markdown]
# Comparison between Mean, Median, and Mode for each individual feature

# %%
m=['Mean','Median','Mode']

a=[mean1,med1,mode1]
b=[mean2,med2,mode2]
c=[mean3,med3,mode3]
d=[mean4,med4,mode4]
e=[mean5,med5,mode5]
f=[mean6,med6,mode6]

# %% [markdown]
# #### Feature: Sale amount

# %% [markdown]
# Line plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(m,a,marker='^',color='r')
for i, value in enumerate(a):
    plt.text(m[i], value, str(round(value, 2)), ha='center', va='bottom')

plt.xlabel('Features')
plt.ylabel('Values')
plt.title('Line plot for Sale amount feature')
plt.show()

# %% [markdown]
# Box plot

# %% [markdown]
# 1. Mean

# %%
plt.boxplot(data['Sale_amount'])
plt.text(0.95, mean1, f'{mean1:.2f}', va='bottom', ha='right', color='red')

plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot of Sale amount with Mean')
plt.xticks([1], ['Sale Amount'])

plt.show()

# %% [markdown]
# 2. Median

# %%
plt.boxplot(data['Sale_amount'])
plt.text(0.95, med1, f'{med1:.2f}', va='bottom', ha='right', color='blue')

plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot of Sale amount with Median')
plt.xticks([1], ['Sale Amount'])

plt.show()

# %% [markdown]
# 3. Mode

# %%
plt.boxplot(data['Sale_amount'])
plt.text(0.95, mode1, f'{mode1:.2f}', va='bottom', ha='right', color='green')

plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot of Sale amount with Mode')
plt.xticks([1], ['Sale Amount'])

plt.show()

# %% [markdown]
# #### Feature: No. of Bedrooms

# %% [markdown]
# Line plot

# %%
plt.plot(m,b,marker='*')
for i, value in enumerate(b):
    plt.text(m[i], value, str(round(value, 2)), ha='center', va='bottom')

plt.xlabel('Features')
plt.ylabel('Values')
plt.title('Line plot for No. of Bedrooms feature')
plt.show()

# %% [markdown]
# Box plot

# %% [markdown]
# 1. Mean

# %%
fig, ax = plt.subplots(figsize=(8, 6)) 
ax.boxplot(data['Beds'])

ax.text(0.95, mean2, f'{mean2:.2f}', va='center', ha='left', color='red')

ax.set_xlabel('Data')
ax.set_ylabel('Values')
ax.set_title('Box Plot of No. of Bedrooms with Mean')

ax.set_xticklabels(['Beds'])

plt.show()

# %% [markdown]
# 2. Median

# %%
fig, ax = plt.subplots(figsize=(8, 6)) 
ax.boxplot(data['Beds'])

ax.text(0.95, med2, f'{med2:.2f}', va='center', ha='left', color='blue')

ax.set_xlabel('Data')
ax.set_ylabel('Values')
ax.set_title('Box Plot of No. of Bedrooms with Median')

ax.set_xticklabels(['Beds'])

plt.show()

# %% [markdown]
# By observiong the boxplot, the median of the number of Bedrooms is 3.00. There are a few outliers  in the number of Bedrooms. These outliers show a vast difference from the median value.

# %% [markdown]
# 3. Mode

# %%
fig, ax = plt.subplots(figsize=(8, 6)) 
ax.boxplot(data['Beds'])

ax.text(0.95, mode2, f'{mode2:.2f}', va='center', ha='left', color='green')

ax.set_xlabel('Data')
ax.set_ylabel('Values')
ax.set_title('Box Plot of No. of Bedrooms with Mode')

ax.set_xticklabels(['Beds'])

plt.show()

# %% [markdown]
# #### Feature: No.of Bathrooms

# %% [markdown]
# Line plot

# %%
plt.plot(m,c,marker='p',color='green')
for i, value in enumerate(c):
    plt.text(m[i], value, str(round(value, 2)), ha='center', va='bottom')

plt.xlabel('Features')
plt.ylabel('Values')
plt.title('Line plot for No. of Bathrooms feature')
plt.show()

# %% [markdown]
# Box plot

# %% [markdown]
# 1. Mean

# %%
fig, ax = plt.subplots(figsize=(8, 6)) 
ax.boxplot(data['Baths'])

ax.text(0.95, mean3, f'{mean3:.2f}', va='center', ha='left', color='red')

ax.set_xlabel('Data')
ax.set_ylabel('Values')
ax.set_title('Box Plot of No. of Bathrooms with Mean')

ax.set_xticklabels(['Baths'])

plt.show()

# %% [markdown]
# 2. Median

# %%
fig, ax = plt.subplots(figsize=(8, 6)) 
ax.boxplot(data['Baths'])

ax.text(0.95, med3, f'{med3:.2f}', va='center', ha='left', color='blue')

ax.set_xlabel('Data')
ax.set_ylabel('Values')
ax.set_title('Box Plot of No. of Bathrooms with Median')

ax.set_xticklabels(['Baths'])

plt.show()

# %% [markdown]
# 3. Mode

# %%
fig, ax = plt.subplots(figsize=(8, 6)) 
ax.boxplot(data['Baths'])

ax.text(0.95, mode3, f'{mode3:.2f}', va='center', ha='left', color='green')

ax.set_xlabel('Data')
ax.set_ylabel('Values')
ax.set_title('Box Plot of No. of Bathrooms with Mode')

ax.set_xticklabels(['Baths'])

plt.show()

# %% [markdown]
# #### Feature: Sqft of Home

# %% [markdown]
# Line plot

# %%
plt.plot(m,d,marker='^',color='brown')
for i, value in enumerate(d):
    plt.text(m[i], value, str(round(value, 2)), ha='center', va='bottom')

plt.xlabel('Features')
plt.ylabel('Values')
plt.title('Line plot for Sqft of Home feature')
plt.show()

# %% [markdown]
# Box plot

# %% [markdown]
# 1. Mean

# %%
plt.boxplot(data['Sqft_home'])
plt.text(0.95, mean4, f'{mean4:.2f}', va='bottom', ha='right', color='red')

plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot of Sqft of Home with Mean')
plt.xticks([1], ['Sqft of Home'])

plt.show()

# %% [markdown]
# 2. Median

# %%
plt.boxplot(data['Sqft_home'])
plt.text(0.95, med4, f'{med4:.2f}', va='bottom', ha='right', color='blue')

plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot of Sqft of Home with Median')
plt.xticks([1], ['Sqft of Home'])

plt.show()

# %% [markdown]
# 3. Mode

# %%
plt.boxplot(data['Sqft_home'])
plt.text(0.95, mode4, f'{mode4:.2f}', va='bottom', ha='right', color='green')

plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot of Sqft of Home with Mode')
plt.xticks([1], ['Sqft of Home'])

plt.show()

# %% [markdown]
# #### Feature: Sqft of lot

# %% [markdown]
# Line plot

# %%
plt.plot(m,e,marker='*',color='orange')
for i, value in enumerate(e):
    plt.text(m[i], value, str(round(value, 2)), ha='center', va='bottom')

plt.xlabel('Features')
plt.ylabel('Values')
plt.title('Line plot for Sqft of lot feature')
plt.show()

# %% [markdown]
# Box plot

# %% [markdown]
# 1. Mean

# %%
plt.boxplot(data['Sqft_lot'])
plt.text(0.95, mean5, f'{mean5:.2f}', va='bottom', ha='right', color='red')

plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot of Sqft of lot with Mean')
plt.xticks([1], ['Sqft of lot'])

plt.show()

# %% [markdown]
# 2. Median

# %%
plt.boxplot(data['Sqft_lot'])
plt.text(0.95, med5, f'{med5:.2f}', va='bottom', ha='right', color='blue')

plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot of Sqft of lot with Median')
plt.xticks([1], ['Sqft of lot'])

plt.show()

# %% [markdown]
# 3. Mode

# %%
plt.boxplot(data['Sqft_lot'])
plt.text(0.95, mode5, f'{mode5:.2f}', va='bottom', ha='right', color='green')

plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot of Sqft of lot with Mode')
plt.xticks([1], ['Sqft of lot'])

plt.show()

# %% [markdown]
# #### Feature: Build year

# %% [markdown]
# Line plot

# %%
plt.plot(m,f,marker='p',color='maroon')
for i, value in enumerate(f):
    plt.text(m[i], value, str(round(value, 2)), ha='center', va='bottom')

plt.xlabel('Features')
plt.ylabel('Values')
plt.title('Line plot for Build year feature')
plt.show()

# %% [markdown]
# Box plot

# %% [markdown]
# 1. Mean

# %%
plt.boxplot(data['Build_year'])
plt.text(0.95, mean6, f'{mean6:.2f}', va='bottom', ha='right', color='red')

plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot of Build year with Mean')
plt.xticks([1], ['Build year'])

plt.show()

# %% [markdown]
# 2. Median

# %%
plt.boxplot(data['Build_year'])
plt.text(0.95, med6, f'{med6:.2f}', va='bottom', ha='right', color='blue')

plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot of Build year with Median')
plt.xticks([1], ['Build year'])

plt.show()

# %% [markdown]
# 3. Mode

# %%
plt.boxplot(data['Build_year'])
plt.text(0.95, mode6, f'{mode6:.2f}', va='bottom', ha='right', color='green')

plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot of Build year with Mode')
plt.xticks([1], ['Build year'])

plt.show()

# %% [markdown]
# Line Plot for comparision between mean, median, and mode of all these features

# %%
features=['Sale Amount','Beds','Baths','Sqft_home','Sqft_lot','Build_year']

mean=[mean1,mean2,mean3,mean4,mean5,mean6]
med=[med1,med2,med3,med4,med5,med6]
mode=[mode1,mode2,mode3,mode4,mode5,mode6]

# %%
plt.plot(features, mean, marker='o', label='Mean')
plt.plot(features, med, marker='s', label='Median')
plt.plot(features, mode, marker='^', label='Mode')

plt.xlabel('Features')
plt.ylabel('Values')
plt.title('Line plot of Mean, Median, and Mode')
plt.legend()

plt.show()

# %% [markdown]
# ### 2. Measures of Variability

# %% [markdown]
# Range: The difference between the maximum and minimum values in the dataset.

# %%
print("Range of Sale amount: ", max(data['Sale_amount'])-min(data['Sale_amount']))
# Out:
# Range of Sale amount:  9483000

# %%
print("Range of No. of Bedrooms: ", max(data['Beds'])-min(data['Beds']))
# Out:
# Range of No. of Bedrooms:  28

# %%
print("Range of No. of Bathrooms: ", max(data['Baths'])-min(data['Baths']))
# Out:
# Range of No. of Bathrooms:  42.5

# %%
print("Range of Square feet of home: ", max(data['Sqft_home'])-min(data['Sqft_home']))
# Out:
# Range of Square feet of home:  139928

# %%
print("Range of Square feet of lot: ", max(data['Sqft_lot'])-min(data['Sqft_lot']))
# Out:
# Range of Square feet of lot:  3350073.2

# %% [markdown]
# Variance: The average squared deviation from the mean.

# %%
print("Variance of Sale amount: ", data['Sale_amount'].var().round(3))
# Out:
# Variance of Sale amount:  116486444699.691

# %%
print("Variance of No. of Bedrooms: ", data['Beds'].var().round(3))
# Out:
# Variance of No. of Bedrooms:  1.092

# %%
print("Variance of No. of Bathrooms: ", data['Baths'].var().round(3))
# Out:
# Variance of No. of Bathrooms:  1.123

# %%
print("Variance of Square feet of home: ", data['Sqft_home'].var().round(3))
# Out:
# Variance of Square feet of home:  2784095.636

# %%
print("Variance of Square feet of lot: ", data['Sqft_lot'].var().round(3))
# Out:
# Variance of Square feet of lot:  5381639256.175

# %% [markdown]
# Standard Deviation: The square root of the variance, providing a measure of dispersion around the mean.

# %%
std1=data['Sale_amount'].std().round(3)
print("Standard deviation of Sale amount: ", std1)
# Out:
# Standard deviation of Sale amount:  341301.106

# %%
std2=data['Beds'].std().round(3)
print("Standard deviation of No. of Bedrooms: ", std2)
# Out:
# Standard deviation of No. of Bedrooms:  1.045

# %%
std3=data['Baths'].std().round(3)
print("Standard deviation of No. of Bathrooms: ", std3)
# Out:
# Standard deviation of No. of Bathrooms:  1.06

# %%
std4=data['Sqft_home'].std().round(3)
print("Standard deviation of Square feet of home: ", std4)
# Out:
# Standard deviation of Square feet of home:  1668.561

# %%
std5=data['Sqft_lot'].std().round(3)
print("Standard deviation of Square feet of lot: ",std5 )
# Out:
# Standard deviation of Square feet of lot:  73359.657

# %% [markdown]
# Interquartile Range (IQR): The range between the first quartile (25th percentile) and the third quartile (75th percentile).

# %%
lst=data['Sale_amount'].copy()
series = pd.Series(lst)
q1 = series.quantile(0.25)
q3 = series.quantile(0.75)
iqr1 = q3 - q1
print("Interquartile Range (IQR) of the feature Sale_amount: ", iqr1)
# Out:
# Interquartile Range (IQR) of the feature Sale_amount:  209025.0

# %%
lst=data['Beds'].copy()
series = pd.Series(lst)
q1 = series.quantile(0.25)
q3 = series.quantile(0.75)
iqr1 = q3 - q1
print("Interquartile Range (IQR) of the feature Beds: ", iqr1)
# Out:
# Interquartile Range (IQR) of the feature Beds:  1.0

# %%
lst=data['Baths'].copy()
series = pd.Series(lst)
q1 = series.quantile(0.25)
q3 = series.quantile(0.75)
iqr1 = q3 - q1
print("Interquartile Range (IQR) of the feature Baths: ", iqr1)
# Out:
# Interquartile Range (IQR) of the feature Baths:  1.0

# %%
lst=data['Sqft_home'].copy()
series = pd.Series(lst)
q1 = series.quantile(0.25)
q3 = series.quantile(0.75)
iqr1 = q3 - q1
print("Interquartile Range (IQR) of the feature Sqft_home: ", iqr1)
# Out:
# Interquartile Range (IQR) of the feature Sqft_home:  1090.5

# %%
lst=data['Sqft_lot'].copy()
series = pd.Series(lst)
q1 = series.quantile(0.25)
q3 = series.quantile(0.75)
iqr1 = q3 - q1
print("Interquartile Range (IQR) of the feature Sqft_lot: ", iqr1)
# Out:
# Interquartile Range (IQR) of the feature Sqft_lot:  7405.6

# %% [markdown]
# #### Feature: Sale amount

# %% [markdown]
# Violen plot

# %%
import seaborn as sns

sns.violinplot(data=data['Sale_amount'])
plt.xlabel('Feature')
plt.ylabel('Value')
plt.title('Violin Plot of Sale amount')
plt.text(0.5, 0.9, f'Standard Deviation: {std1:.2f}', ha='center', va='center', transform=plt.gca().transAxes)
plt.xticks([0], ['Sale amount'])
plt.show()

# %% [markdown]
# #### Feature: No. of Bedrooms

# %% [markdown]
# Violen plot

# %%
sns.violinplot(data=data['Beds'],color='orange')
plt.xlabel('Feature')
plt.ylabel('Value')
plt.title('Violin Plot of No. of Bedrooms')
plt.text(0.5, 0.9, f'Standard Deviation: {std2:.2f}', ha='center', va='center', transform=plt.gca().transAxes)
plt.xticks([0], ['No. of Bedrooms'])
plt.show()

# %% [markdown]
# #### Feature: No. of Bathrooms

# %% [markdown]
# Violen plot

# %%
sns.violinplot(data=data['Baths'],color='green')
plt.xlabel('Feature')
plt.ylabel('Value')
plt.title('Violin Plot of No. of Bathrooms')
plt.text(0.5, 0.9, f'Standard Deviation: {std3:.2f}', ha='center', va='center', transform=plt.gca().transAxes)
plt.xticks([0], ['No. of Bathrooms'])
plt.show()

# %% [markdown]
# #### Feature: Sqft of Home

# %% [markdown]
# Violen plot

# %%
sns.violinplot(data=data['Sqft_home'],color='yellow')
plt.xlabel('Feature')
plt.ylabel('Value')
plt.title('Violin Plot of Sqft of home')
plt.text(0.5, 0.9, f'Standard Deviation: {std4:.2f}', ha='center', va='center', transform=plt.gca().transAxes)
plt.xticks([0], ['Sqft of home'])
plt.show()

# %% [markdown]
# #### Feature: Sqft of lot

# %% [markdown]
# Violen plot

# %%
sns.violinplot(data=data['Sqft_lot'],color='red')
plt.xlabel('Feature')
plt.ylabel('Value')
plt.title('Violin Plot of Sqft of lot')
plt.text(0.5, 0.9, f'Standard Deviation: {std5:.2f}', ha='center', va='center', transform=plt.gca().transAxes)
plt.xticks([0], ['Sqft of lot'])
plt.show()

# %% [markdown]
# ### 3. Measures of Distribution

# %% [markdown]
# Skewness: A measure of the asymmetry of the dataset's distribution.

# %% [markdown]
# Kurtosis: A measure of the peakedness or flatness of the dataset's distribution.

# %%
series = pd.Series(data['Sale_amount'])
skewness1 = series.skew().round(3)
kurt1 = series.kurtosis().round(3)

print("Skewness in the feature Sale amount: ", skewness1)
print("Kurtosis in the feature Sale amount: ", kurt1)
# Out:
# Skewness in the feature Sale amount:  5.874
# Kurtosis in the feature Sale amount:  78.05

# %%
series = pd.Series(data['Beds'])
skewness2 = series.skew().round(3)
kurt2 = series.kurtosis().round(3)

print("Skewness in the feature No. of Bedrooms: ", skewness2)
print("Kurtosis in the feature No. of Bedrooms: ", kurt2)
# Out:
# Skewness in the feature No. of Bedrooms:  4.664
# Kurtosis in the feature No. of Bedrooms:  86.874

# %%
series = pd.Series(data['Baths'])
skewness3 = series.skew().round(3)
kurt3 = series.kurtosis().round(3)

print("Skewness in the feature No. of Bathrooms: ", skewness3)
print("Kurtosis in the feature No. of Bathrooms: ", kurt3)
# Out:
# Skewness in the feature No. of Bathrooms:  6.665
# Kurtosis in the feature No. of Bathrooms:  213.521

# %%
series = pd.Series(data['Sqft_home'])
skewness4 = series.skew().round(3)
kurt4 = series.kurtosis().round(3)

print("Skewness in the feature Sqft_home: ", skewness4)
print("Kurtosis in the feature Sqft_home: ", kurt4)
# Out:
# Skewness in the feature Sqft_home:  53.829
# Kurtosis in the feature Sqft_home:  4423.736

# %%
series = pd.Series(data['Sqft_lot'])
skewness5 = series.skew().round(3)
kurt5 = series.kurtosis().round(3)

print("Skewness in the feature Sqft_lot: ", skewness5)
print("Kurtosis in the feature Sqft_lot: ", kurt5)
# Out:
# Skewness in the feature Sqft_lot:  19.154
# Kurtosis in the feature Sqft_lot:  579.253

# %% [markdown]
# Line Plot for comparision between Skewness, Kurtosis of all these features

# %%
features=['Sale Amount','Beds','Baths','Sqft_home','Sqft_lot']

skewness=[skewness1,skewness2,skewness3,skewness4,skewness5]
kurt=[kurt1,kurt2,kurt3,kurt4,kurt5]

# %%
plt.plot(features, skewness, marker='o', label='Skewness')
plt.plot(features, kurt, marker='s', label='Kurtosis')

plt.xlabel('Features')
plt.ylabel('Values')
plt.title('Line plot of Skewness, Kurtosis')
plt.legend()

plt.show()

# %% [markdown]
# Percentiles: Values below which a certain percentage of the dataset falls. For example, the median is the 50th percentile.

# %%
lst=data['Sale_amount'].copy()
series = pd.Series(lst)
p1 = series.quantile(0.25)
p2 = series.quantile(0.50)
p3 = series.quantile(0.75)
print("25th percentile of the feature Sale amount: ",p1)
print("50th percentile of the feature Sale amount: ",p2)
print("75th percentile of the feature Sale amount: ",p3)
# Out:
# 25th percentile of the feature Sale amount:  165975.0
# 50th percentile of the feature Sale amount:  249000.0
# 75th percentile of the feature Sale amount:  375000.0

# %%
lst=data['Sale_amount'].copy()
series = pd.Series(lst)
p1 = series.quantile(0.25)
p2 = series.quantile(0.50)
p3 = series.quantile(0.75)
print("25th percentile of the feature Sale amount: ",p1)
print("50th percentile of the feature Sale amount: ",p2)
print("75th percentile of the feature Sale amount: ",p3)
# Out:
# 25th percentile of the feature Sale amount:  165975.0
# 50th percentile of the feature Sale amount:  249000.0
# 75th percentile of the feature Sale amount:  375000.0

# %%
lst=data['Beds'].copy()
series = pd.Series(lst)
p4 = series.quantile(0.25)
p5 = series.quantile(0.50)
p6 = series.quantile(0.75)
print("25th percentile of the feature No. of Bedrooms: ",p4)
print("50th percentile of the feature No. of Bedrooms: ",p5)
print("75th percentile of the feature No. of Bedrooms: ",p6)
# Out:
# 25th percentile of the feature No. of Bedrooms:  3.0
# 50th percentile of the feature No. of Bedrooms:  3.0
# 75th percentile of the feature No. of Bedrooms:  4.0

# %%
lst=data['Baths'].copy()
series = pd.Series(lst)
p7 = series.quantile(0.25)
p8 = series.quantile(0.50)
p9 = series.quantile(0.75)
print("25th percentile of the feature No. of Bathrooms: ",p7)
print("50th percentile of the feature No. of Bathrooms: ",p8)
print("75th percentile of the feature No. of Bathrooms: ",p9)
# Out:
# 25th percentile of the feature No. of Bathrooms:  2.0
# 50th percentile of the feature No. of Bathrooms:  2.0
# 75th percentile of the feature No. of Bathrooms:  3.0

# %%
lst=data['Sqft_home'].copy()
series = pd.Series(lst)
p10 = series.quantile(0.25)
p11 = series.quantile(0.50)
p12 = series.quantile(0.75)
print("25th percentile of the feature Sqft_home: ",p10)
print("50th percentile of the feature Sqft_home: ",p11)
print("75th percentile of the feature Sqft_home: ",p12)
# Out:
# 25th percentile of the feature Sqft_home:  1389.0
# 50th percentile of the feature Sqft_home:  1826.0
# 75th percentile of the feature Sqft_home:  2479.5

# %%
lst=data['Sqft_lot'].copy()
series = pd.Series(lst)
p13 = series.quantile(0.25)
p14 = series.quantile(0.50)
p15 = series.quantile(0.75)
print("25th percentile of the feature Sqft_home: ",p13)
print("50th percentile of the feature Sqft_home: ",p14)
print("75th percentile of the feature Sqft_home: ",p15)
# Out:
# 25th percentile of the feature Sqft_home:  6098.0
# 50th percentile of the feature Sqft_home:  8712.0
# 75th percentile of the feature Sqft_home:  13503.6

# %% [markdown]
# Bar plot of 25th, 50th, 75th percentiles for each feature

# %%
p_a = [p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12, p13, p14, p15]
per = []
for i in range(5):
    per.append('25th percentile')
    per.append('50th percentile')
    per.append('75th percentile')

p = pd.DataFrame(p_a)
p.reset_index(drop=True, inplace=True)

groups = np.array_split(p, np.ceil(len(p) / 3))

num_groups = len(groups)
num_cols = min(num_groups, 3)
num_rows = np.ceil(num_groups / num_cols).astype(int)

fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, 4 * num_rows))

if num_groups == 1:
    axs = np.array([axs])

for i, group in enumerate(groups):
    row = i // num_cols
    col = i % num_cols
    ax = axs[row, col]
    x = np.arange(3)
    bar_width = 0.3
    random_colors = np.random.rand(3, 3)
    bars = ax.bar(x, group.values.flatten(), bar_width, color=random_colors)

    ax.set_xlabel('Percentiles')
    ax.set_ylabel('Value')
    ax.set_title(features[i])
    ax.set_xticks(x)
    ax.set_xticklabels(per[i * 3: (i + 1) * 3])

    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points',
                    ha='center', va='bottom')

plt.tight_layout()
plt.show()
# Out:
# c:\Users\Sasha\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %% [markdown]
# ### 4. Count and Missing Values

# %% [markdown]
# Count: The number of observations in the dataset.

# %% [markdown]
# Missing Values: The number of missing or null values in the dataset.

# %%
data.isnull().sum()
# Out:
# Record         0
# Sale_amount    0
# Sale_date      0
# Beds           0
# Baths          0
# Sqft_home      0
# Sqft_lot       0
# Type           0
# Build_year     0
# Town           0
# University     0
# dtype: int64

# %% [markdown]
# According to the above output, there are "No missing values" in the Dataset

# %% [markdown]
# ### 5. Correlation
#
# Correlation: A measure of the linear relationship between two variables. It can range from -1 to 1, indicating the strength and direction of the relationship.

# %%
data_num = data.select_dtypes(include=['int', 'float'])
correlation = data_num.corr()
correlation_s = correlation.style.background_gradient(cmap='YlOrRd')
correlation_s
# Out:
# <style type="text/css">
# #T_1a5c2_row0_col0, #T_1a5c2_row1_col1, #T_1a5c2_row2_col2, #T_1a5c2_row3_col3, #T_1a5c2_row4_col4, #T_1a5c2_row5_col5, #T_1a5c2_row6_col6 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_1a5c2_row0_col1, #T_1a5c2_row0_col2, #T_1a5c2_row0_col3, #T_1a5c2_row0_col4, #T_1a5c2_row0_col5, #T_1a5c2_row0_col6, #T_1a5c2_row1_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_1a5c2_row1_col2 {
#   background-color: #feaf4b;
#   color: #000000;
# }
# #T_1a5c2_row1_col3 {
#   background-color: #fd6e33;
#   color: #f1f1f1;
# }
# #T_1a5c2_row1_col4 {
#   background-color: #fd7836;
#   color: #f1f1f1;
# }
# #T_1a5c2_row1_col5 {
#   background-color: #fee38b;
#   color: #000000;
# }
# #T_1a5c2_row1_col6 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_1a5c2_row2_col0 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_1a5c2_row2_col1 {
#   background-color: #fd953f;
#   color: #000000;
# }
# #T_1a5c2_row2_col3 {
# ...

# %%
data.columns
# Out:
# Index(['Record', 'Sale_amount', 'Sale_date', 'Beds', 'Baths', 'Sqft_home',
#        'Sqft_lot', 'Type', 'Build_year', 'Town', 'University'],
#       dtype='object')

# %% [markdown]
# ### Qualitative Features

# %%
data_str=data[['Sale_date','Type','Build_year','Town','University']]
print('Other features are ')
for i in range(len(data_str.columns)):
    print('\'',data_str.columns[i],'\';',end=' ')
# Out:
# Other features are
# ' Sale_date '; ' Type '; ' Build_year '; ' Town '; ' University ';

# %% [markdown]
# ### 1. Unique values for each feature

# %% [markdown]
# #### Feature: Sale date

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Sasha\OneDrive\Desktop\Emperical Analysis\DescriptiveStatistics.ipynb Cell 173 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Sasha/OneDrive/Desktop/Emperical%20Analysis/DescriptiveStatistics.ipynb#Y334sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Sasha/OneDrive/Desktop/Emperical%20Analysis/DescriptiveStatistics.ipynb#Y334sZmlsZQ%3D%3D?line=1'>2</a> from wordcloud import WordCloud
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
u1 = data_str['Sale_date'].nunique()
ua = data_str['Sale_date'].unique()
uA= ', '.join(str(val) for val in ua)
print("No. of unique values in the feature Sale date: ",u1)
print('\n')
print("The distinct values of the feature Sale date: ")
uA
# Out:
# No. of unique values in the feature Sale date:  172
#
#
# The distinct values of the feature Sale date:
# ...

# %% [markdown]
# Extracting month from date

# %%
data_str['Sale_date'] = pd.to_datetime(data_str['Sale_date'])
data_str_month=data_str.copy()
data_str_month['Month'] = data_str_month['Sale_date'].dt.strftime('%B')
# Out:
# C:\Users\Sasha\AppData\Local\Temp\ipykernel_12476\2216474692.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_str['Sale_date'] = pd.to_datetime(data_str['Sale_date'])

# %% [markdown]
# Word Cloud

# %%
ua = data_str_month['Month'].unique()
text = ",".join(ua)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(7, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Bar Plot

# %%
p = data_str_month['Month'] .value_counts()

p = p.sort_index()

plt.bar(p.index, p.values,color='blue')
for i, v in enumerate(p.values):
    plt.text(p.index[i], v, str(v), ha='center', va='bottom')

plt.xlabel('Distinct Sale month')
plt.ylabel('Frequency')
plt.title('Frequency of Distinct Sale month')
plt.show()

# %% [markdown]
# Pie chart

# %%
word_counts = data_str_month['Month'].value_counts()

word_percentages = word_counts / len(data_str_month) * 100

plt.pie(word_percentages, labels=word_percentages.index, autopct='%1.1f%%', shadow=True)

plt.title("Data Distribution monthwise")

plt.axis('equal')

plt.show()

# %% [markdown]
# #### Feature: Type

# %%
u2 = data_str['Type'].nunique()
ub = data_str['Type'].unique()
uB= ', '.join(str(val) for val in ub)
print("No. of unique values in the feature Type: ",u2)
print('\n')
print("The distinct values of the feature Type: ")
uB
# Out:
# No. of unique values in the feature Type:  3
#
#
# The distinct values of the feature Type:
# 'Single Family, Multi Family, Multiple Occupancy'

# %% [markdown]
# Word Cloud

# %%
text = ",".join(ub)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(7, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Bar Plot

# %%
p = data_str['Type'].value_counts()

p = p.sort_index()

plt.bar(p.index, p.values,color='green')
for i, v in enumerate(p.values):
    plt.text(p.index[i], v, str(v), ha='center', va='bottom')

plt.xlabel('Distinct Family Types')
plt.ylabel('Frequency')
plt.title('Frequency of Distinct Family Types')
plt.show()

# %% [markdown]
# Pie chart

# %%
word_counts = data_str['Type'].value_counts()

word_percentages = word_counts / len(data_str) * 100

colors=['yellow','green','orange']

plt.pie(word_percentages, labels=word_percentages.index, autopct='%1.1f%%', shadow=True,colors=colors)

plt.title("Data Distribution monthwise")

plt.axis('equal')

plt.show()

# %% [markdown]
# #### Feature: Build year

# %%
u3 = data_str['Build_year'].nunique()
uc = data_str['Build_year'].unique()
uC= ', '.join(str(val) for val in uc)
print("No. of unique values in the feature Build year: ",u3)
print('\n')
print("The distinct values of the feature Build year: ")
uC
# Out:
# No. of unique values in the feature Build year:  158
#
#
# The distinct values of the feature Build year:
# ...

# %% [markdown]
# Bar Plot

# %%
p = data_str['Build_year'].value_counts()

p = p.sort_index()

plt.bar(p.index, p.values,color='orange')
plt.xlabel('Distinct Build years')
plt.ylabel('Frequency')
plt.title('Frequency of Distinct Build years')
plt.show()

# %% [markdown]
# Pie charts

# %%
ranges = [(1800, 1850), (1850, 1900), (1900, 1950), (1950, 2000),(2000,2023)]

years_in_ranges = []
for range_start, range_end in ranges:
    years_in_range = len(data_str[(data_str['Build_year'] >= range_start) & (data_str['Build_year'] < range_end)])
    years_in_ranges.append(years_in_range)

total_years = sum(years_in_ranges)
percentages = [(years / total_years) * 100 for years in years_in_ranges]

labels = [f"{range_start}-{range_end}" for (range_start, range_end) in ranges]

plt.pie(percentages, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title("Year Distribution")
plt.axis('equal')
plt.show()

# %% [markdown]
# #### Feature: Town

# %%
u4 = data_str['Town'].nunique()
ud = data_str['Town'].unique()
uD = ', '.join(str(val) for val in ud)
print("No. of unique values in the feature Town: ",u4)
print('\n')
print("The distinct values of the Town: ")
uD
# Out:
# No. of unique values in the feature Town:  50
#
#
# The distinct values of the Town:
# 'Ames, IA, Amherst, MA, Ann Arbor, MI, Athens, GA, Berkeley, CA, Binghamton, NY, Blacksburg, VA, Bloomington, IL, Bloomington, IN, Boulder, CO, Bozeman, MT, Burlington, VT, Cambridge, MA, Champaign-Urbana, IL, Chapel Hill, NC, Charlottesville, VA, Claremont, CA, College Station, TX, Columbia, MO, Corvallis, OR, East Lansing, MI, Eugene, OR, Fargo, ND, Fayetteville, AR, Flagstaff, AZ, Fort Collins, CO, Gainesville, FL, Grand Forks, ND, Hartford, CT, Iowa City, IA, Ithaca, NY, Lafayette, IN, Lawrence, KS, Lexington, KY, Lincoln, NE, Logan, UT, Madison, WI, Manhattan, KS, Minneapolis, MN, Morgantown, WV, Oxford, MS, Pittsburgh, PA, San Luis Obispo, CA, State College, PA, Syracuse, NY, Tacoma, WA, Tallahassee, FL, Tempe, AZ, Tuscaloosa, AL, Waterloo-Cedar Falls, IA'

# %% [markdown]
# Word Cloud

# %%
text = ",".join(ud)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(7, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('on')
plt.show()

# %% [markdown]
# Bar Plot

# %%
p = data_str['Town'].value_counts().sort_index()

groups = np.array_split(p, np.ceil(len(p) / 3))

num_groups = len(groups)
num_cols = min(num_groups, 3)
num_rows = np.ceil(num_groups / num_cols).astype(int)

fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, 4 * num_rows), sharey=True)

if num_groups == 1:
    axs = [axs]

for i, group in enumerate(groups):
    row = i // num_cols
    col = i % num_cols
    ax = axs[row][col]
    bars = ax.bar(group.index, group.values, color='brown')
    ax.set_xlabel('Town')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Group {i+1}')

    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points',
                    ha='center', va='bottom')

plt.tight_layout()

plt.show()

# %% [markdown]
# As the number of categories in the feature 'Town' are more, Pie chart is not recommended as it will be very clumsy

# %% [markdown]
# #### Feature: University

# %%
u5 = data_str['University'].nunique()
ue = data_str['University'].unique()
uE= ', '.join(str(val) for val in ue)
print("No. of unique values in the feature University: ",u5)
print('\n')
print("The distinct values of the University: ")
uE
# Out:
# No. of unique values in the feature University:  50
#
#
# The distinct values of the University:
# ...

# %%
text = ",".join(ue)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(7, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('on')
plt.show()

# %%
p = data_str['University'].value_counts().sort_index()

groups = np.array_split(p, np.ceil(len(p) / 3))

num_groups = len(groups)
num_cols = min(num_groups, 3)
num_rows = np.ceil(num_groups / num_cols).astype(int)

fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, 4 * num_rows), sharey=True)

if num_groups == 1:
    axs = [axs]

for i, group in enumerate(groups):
    row = i // num_cols
    col = i % num_cols
    ax = axs[row][col]
    bars = ax.bar(group.index, group.values, color='r')
    ax.set_xlabel('Town')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Group {i+1}')

    ax.set_xticks(range(len(group.index)))

    ax.set_xticklabels([name[:10] + '...' if len(name) > 10 else name for name in group.index], rotation=90, ha='left')
    
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points',
                    ha='center', va='bottom')

plt.tight_layout()

plt.show()

# %% [markdown]
# As the number of categories in the feature 'University' are more, Pie chart is not recommended as it will be very clumsy

# %% [markdown]
# Scatter plots
